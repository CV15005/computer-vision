# %% [markdown]
# ## Задание
# 1. Считать любое из тестовых изображений (в папке test_images)
# 2. Выполнить сегментацию объектов подходящим методом
# 3. Визуализировать метки сегментации на исходном изображении (например, выделить отдельные объекты разными цветами)
